# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
#import mpld3

# %%
df = pd.read_csv('../output/dengue_processed_for_regression.csv')
df
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2016      Ang Thong            286      75.0      27.0      13.0
# 2    2016        Bangkok          14932      75.0      27.0      13.0
# 3    2016      Bueng Kan           1266      75.0      27.0      13.0
# 4    2016       Buri Ram           1500      76.6      27.4       8.5
# ..    ...            ...            ...       ...       ...       ...
# 380  2020     Udon Thani            941      75.0      27.0      13.0
# 381  2020    Uthai Thani            247      75.0      27.0      13.0
# 382  2020      Uttaradit            587      75.0      27.0      13.0
# 383  2020           Yala            436      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day
# 0        39.0   1638.0       130
# 1        39.0   1638.0       130
# 2        39.0   1638.0       130
# 3        39.0   1638.0       130
# 4        43.2   1370.7        93
# ..        ...      ...       ...
# 380      39.0   1638.0       130
# 381      39.0   1638.0       130
# 382      39.0   1638.0       130
# 383      39.0   1638.0       130
# 384      39.0   1638.0       130
#
# [385 rows x 9 columns]

# %%
df = df.loc[df['year'] == 2019]
df
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 231  2019  Amnat Charoen            549      75.0      27.0      13.0
# 232  2019      Ang Thong            281      75.0      27.0      13.0
# 233  2019        Bangkok          14020      75.0      27.0      13.0
# 234  2019      Bueng Kan            873      75.0      27.0      13.0
# 235  2019       Buri Ram           3860      75.7      27.6      12.1
# ..    ...            ...            ...       ...       ...       ...
# 303  2019     Udon Thani           1628      69.6      27.9       8.5
# 304  2019    Uthai Thani            689      75.0      27.0      13.0
# 305  2019      Uttaradit            588      67.5      28.8      13.0
# 306  2019           Yala           1456      81.0      27.4      18.0
# 307  2019       Yasothon            870      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day
# 231      39.0   1638.0       130
# 232      39.0   1638.0       130
# 233      39.0   1638.0       130
# 234      39.0   1638.0       130
# 235      40.2   1261.7       114
# ..        ...      ...       ...
# 303      42.5   1285.7       130
# 304      39.0   1638.0       130
# 305      43.0    842.8        77
# 306      38.9   2097.2       173
# 307      39.0   1638.0       130
#
# [77 rows x 9 columns]

# %%
df = df.rename(columns={'province': 'Province'})
df
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 231  2019  Amnat Charoen            549      75.0      27.0      13.0
# 232  2019      Ang Thong            281      75.0      27.0      13.0
# 233  2019        Bangkok          14020      75.0      27.0      13.0
# 234  2019      Bueng Kan            873      75.0      27.0      13.0
# 235  2019       Buri Ram           3860      75.7      27.6      12.1
# ..    ...            ...            ...       ...       ...       ...
# 303  2019     Udon Thani           1628      69.6      27.9       8.5
# 304  2019    Uthai Thani            689      75.0      27.0      13.0
# 305  2019      Uttaradit            588      67.5      28.8      13.0
# 306  2019           Yala           1456      81.0      27.4      18.0
# 307  2019       Yasothon            870      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day
# 231      39.0   1638.0       130
# 232      39.0   1638.0       130
# 233      39.0   1638.0       130
# 234      39.0   1638.0       130
# 235      40.2   1261.7       114
# ..        ...      ...       ...
# 303      42.5   1285.7       130
# 304      39.0   1638.0       130
# 305      43.0    842.8        77
# 306      38.9   2097.2       173
# 307      39.0   1638.0       130
#
# [77 rows x 9 columns]

# %%
coord = pd.read_csv('../../Nuttawut/thailand_lalong.csv')
coord
# Out:
#          Province  latitude  longitude
# 0   Amnat Charoen   15.5100   104.3800
# 1       Ang Thong   14.3500   100.3100
# 2         Bangkok   13.4500   100.3500
# 3       Bueng Kan   18.2300   103.3700
# 4        Buri Ram   15.0000   103.0000
# ..            ...       ...        ...
# 72     Udon Thani   17.2900   102.4600
# 73    Uthai Thani   15.3835   100.0246
# 74      Uttaradit   17.3600   100.5000
# 75           Yala    6.5411   101.2804
# 76       Yasothon   15.5000   104.1000
#
# [77 rows x 3 columns]

# %%
df2 = pd.merge(df,coord,on='Province')
df2
# Out:
#     year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0   2019  Amnat Charoen            549      75.0      27.0      13.0
# 1   2019      Ang Thong            281      75.0      27.0      13.0
# 2   2019        Bangkok          14020      75.0      27.0      13.0
# 3   2019      Bueng Kan            873      75.0      27.0      13.0
# 4   2019       Buri Ram           3860      75.7      27.6      12.1
# ..   ...            ...            ...       ...       ...       ...
# 72  2019     Udon Thani           1628      69.6      27.9       8.5
# 73  2019    Uthai Thani            689      75.0      27.0      13.0
# 74  2019      Uttaradit            588      67.5      28.8      13.0
# 75  2019           Yala           1456      81.0      27.4      18.0
# 76  2019       Yasothon            870      75.0      27.0      13.0
#
#     temp_max  rain_ml  rain_day  latitude  longitude
# 0       39.0   1638.0       130   15.5100   104.3800
# 1       39.0   1638.0       130   14.3500   100.3100
# 2       39.0   1638.0       130   13.4500   100.3500
# 3       39.0   1638.0       130   18.2300   103.3700
# 4       40.2   1261.7       114   15.0000   103.0000
# ..       ...      ...       ...       ...        ...
# 72      42.5   1285.7       130   17.2900   102.4600
# 73      39.0   1638.0       130   15.3835   100.0246
# 74      43.0    842.8        77   17.3600   100.5000
# 75      38.9   2097.2       173    6.5411   101.2804
# 76      39.0   1638.0       130   15.5000   104.1000
#
# [77 rows x 11 columns]

# %%
# np_coord = df2[['latitude', 'longitude','quant_rain']].to_numpy()
np_coord = df2[['latitude', 'longitude','rain_ml']].to_numpy()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(
    init="random",
    n_clusters=3,
    n_init=10,
    max_iter=300,
    random_state=42
)

# %%
kmeans.fit(np_coord)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2,
#        2, 2, 0, 0, 2, 0, 2, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 2, 2, 2, 2,
#        2, 2, 2, 0, 0, 2, 1, 2, 2, 0, 0, 2, 2, 0, 0, 0, 0, 2, 0, 0, 2, 2,
#        2, 2, 2, 0, 1, 0, 2, 0, 2, 0, 0])

# %%
centers =  kmeans.cluster_centers_
centers
# Out:
# array([[  12.14270625,  101.18703437, 1721.03125   ],
#        [  10.9014    ,  100.45875   , 4558.        ],
#        [  15.53572326,  100.82566512,  942.71860465]])

# %%
cluster = pd.DataFrame({'k_n':kmeans.labels_})
cluster
# Out:
#     k_n
# 0     0
# 1     0
# 2     0
# 3     0
# 4     2
# ..  ...
# 72    2
# 73    0
# 74    2
# 75    0
# 76    0
#
# [77 rows x 1 columns]

# %%
df3 = df2.join(cluster)
df3
# Out:
#     year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0   2019  Amnat Charoen            549      75.0      27.0      13.0
# 1   2019      Ang Thong            281      75.0      27.0      13.0
# 2   2019        Bangkok          14020      75.0      27.0      13.0
# 3   2019      Bueng Kan            873      75.0      27.0      13.0
# 4   2019       Buri Ram           3860      75.7      27.6      12.1
# ..   ...            ...            ...       ...       ...       ...
# 72  2019     Udon Thani           1628      69.6      27.9       8.5
# 73  2019    Uthai Thani            689      75.0      27.0      13.0
# 74  2019      Uttaradit            588      67.5      28.8      13.0
# 75  2019           Yala           1456      81.0      27.4      18.0
# 76  2019       Yasothon            870      75.0      27.0      13.0
#
#     temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 0       39.0   1638.0       130   15.5100   104.3800    0
# 1       39.0   1638.0       130   14.3500   100.3100    0
# 2       39.0   1638.0       130   13.4500   100.3500    0
# 3       39.0   1638.0       130   18.2300   103.3700    0
# 4       40.2   1261.7       114   15.0000   103.0000    2
# ..       ...      ...       ...       ...        ...  ...
# 72      42.5   1285.7       130   17.2900   102.4600    2
# 73      39.0   1638.0       130   15.3835   100.0246    0
# 74      43.0    842.8        77   17.3600   100.5000    2
# 75      38.9   2097.2       173    6.5411   101.2804    0
# 76      39.0   1638.0       130   15.5000   104.1000    0
#
# [77 rows x 12 columns]

# %%
df3['k_n'] = df3['k_n'].replace([2],5)
df3['k_n'] = df3['k_n'].replace([0],10)
df3['k_n'] = df3['k_n'].replace([1],100)
df3
# Out:
#     year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0   2019  Amnat Charoen            549      75.0      27.0      13.0
# 1   2019      Ang Thong            281      75.0      27.0      13.0
# 2   2019        Bangkok          14020      75.0      27.0      13.0
# 3   2019      Bueng Kan            873      75.0      27.0      13.0
# 4   2019       Buri Ram           3860      75.7      27.6      12.1
# ..   ...            ...            ...       ...       ...       ...
# 72  2019     Udon Thani           1628      69.6      27.9       8.5
# 73  2019    Uthai Thani            689      75.0      27.0      13.0
# 74  2019      Uttaradit            588      67.5      28.8      13.0
# 75  2019           Yala           1456      81.0      27.4      18.0
# 76  2019       Yasothon            870      75.0      27.0      13.0
#
#     temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 0       39.0   1638.0       130   15.5100   104.3800   10
# 1       39.0   1638.0       130   14.3500   100.3100   10
# 2       39.0   1638.0       130   13.4500   100.3500   10
# 3       39.0   1638.0       130   18.2300   103.3700   10
# 4       40.2   1261.7       114   15.0000   103.0000    5
# ..       ...      ...       ...       ...        ...  ...
# 72      42.5   1285.7       130   17.2900   102.4600    5
# 73      39.0   1638.0       130   15.3835   100.0246   10
# 74      43.0    842.8        77   17.3600   100.5000    5
# 75      38.9   2097.2       173    6.5411   101.2804   10
# 76      39.0   1638.0       130   15.5000   104.1000   10
#
# [77 rows x 12 columns]

# %%
df3 = df3.sort_values(by=['k_n'],ascending=1)
df3
# Out:
#     year             Province  patient_count  humidity  temp_avg  temp_min  \
# 26  2019        Nakhon Pathom           2362      76.2      28.5      14.2
# 23  2019        Maha Sarakham           1355      69.7      28.6      11.5
# 67  2019                Surin           3787      69.4      28.3      11.6
# 66  2019          Surat Thani            553      82.9      27.4      20.1
# 52  2019               Rayong           2733      76.9      28.8      17.5
# ..   ...                  ...            ...       ...       ...       ...
# 47  2019               Phuket            585      75.4      29.2      23.2
# 48  2019         Prachin Buri           1467      69.9      29.6      17.3
# 30  2019  Nakhon Si Thammarat           4388      81.4      27.8      20.4
# 70  2019                 Trat            635      81.0      27.9      18.2
# 50  2019               Ranong            194      78.5      27.7      20.3
#
#     temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 26      40.5    694.1        87   13.4900   100.0300    5
# 23      43.3   1228.2        75   16.1200   103.1600    5
# 67      40.8   1194.2       108   14.5000   103.3400    5
# 66      39.5   1233.1       143    9.6000    99.2000    5
# 52      35.0    946.0        94   12.4000   101.2000    5
# ..       ...      ...       ...       ...        ...  ...
# 47      39.2   1688.8       149    7.5300    98.2400   10
# 48      40.3   1341.4       130   14.0000   101.2500   10
# 30      38.4   2130.8       130    8.2900   100.0000   10
# 70      35.8   5287.3       185   12.2428   102.5175  100
# 50      37.2   3828.7       183    9.5600    98.4000  100
#
# [77 rows x 12 columns]

# %%
df3['k_n'] = df3['k_n'].replace([100],'High')
df3['k_n'] = df3['k_n'].replace([10],'Medium')
df3['k_n'] = df3['k_n'].replace([5],'Low')
df3
# Out:
#     year             Province  patient_count  humidity  temp_avg  temp_min  \
# 26  2019        Nakhon Pathom           2362      76.2      28.5      14.2
# 23  2019        Maha Sarakham           1355      69.7      28.6      11.5
# 67  2019                Surin           3787      69.4      28.3      11.6
# 66  2019          Surat Thani            553      82.9      27.4      20.1
# 52  2019               Rayong           2733      76.9      28.8      17.5
# ..   ...                  ...            ...       ...       ...       ...
# 47  2019               Phuket            585      75.4      29.2      23.2
# 48  2019         Prachin Buri           1467      69.9      29.6      17.3
# 30  2019  Nakhon Si Thammarat           4388      81.4      27.8      20.4
# 70  2019                 Trat            635      81.0      27.9      18.2
# 50  2019               Ranong            194      78.5      27.7      20.3
#
#     temp_max  rain_ml  rain_day  latitude  longitude     k_n
# 26      40.5    694.1        87   13.4900   100.0300     Low
# 23      43.3   1228.2        75   16.1200   103.1600     Low
# 67      40.8   1194.2       108   14.5000   103.3400     Low
# 66      39.5   1233.1       143    9.6000    99.2000     Low
# 52      35.0    946.0        94   12.4000   101.2000     Low
# ..       ...      ...       ...       ...        ...     ...
# 47      39.2   1688.8       149    7.5300    98.2400  Medium
# 48      40.3   1341.4       130   14.0000   101.2500  Medium
# 30      38.4   2130.8       130    8.2900   100.0000  Medium
# 70      35.8   5287.3       185   12.2428   102.5175    High
# 50      37.2   3828.7       183    9.5600    98.4000    High
#
# [77 rows x 12 columns]

# %%
df3 = df3.rename(columns={'k_n': 'rain_amount'})

# %%
# plt = sns.scatterplot(data=df3, x="latitude", y="longitude", hue="k_n" )
# plt.axis('equal')

# %%
#print(min(df3['latitude']),max(df3['latitude']),min(df3['longitude']),max(df3['longitude']))

# %%
# import map
ruh_m = plt.imread('../img/map.jpg')

# %%
# Set edge
maps = pd.DataFrame(data={"lat":[97.313,105.785], "lon":[20.556,5.468]})
maps
# Out:
#        lat     lon
# 0   97.313  20.556
# 1  105.785   5.468

# %%
# Set map edge
BBox = ( maps['lat'].min(), 
         maps['lat'].max(),
         maps['lon'].min(), 
         maps['lon'].max())
BBox
# Out:
# (97.313, 105.785, 5.468, 20.556)

# %%
fig, ax = plt.subplots(figsize = (8,7))
hmax = sns.scatterplot(
    data=df3, x="longitude", y="latitude",
    hue="rain_amount" , palette=['green','blue','red'], 
    size="patient_count" , sizes=(0,500) , alpha = 0.5 )
# ax.scatter(df3.longitude, df3.latitude, alpha=0.3, c=df3.k_n, s=df3.dead_perc*1000)
hmax.scatter(centers[:, 1], centers[:, 0], s=1000, alpha=0.1, c =['blue','red','green'])
hmax.set_title('Plotting Spatial Data on Riyadh Map')
hmax.set_xlim(BBox[0],BBox[1])
hmax.set_ylim(BBox[2],BBox[3])
hmax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
