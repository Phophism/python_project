# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
#import mpld3

# %%
df = pd.read_csv('../Akkapop/output/dengue_processed_for_regression.csv')
df
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2016      Ang Thong            286      75.0      27.0      13.0
# 2    2016        Bangkok          14932      75.0      27.0      13.0
# 3    2016      Bueng Kan           1266      75.0      27.0      13.0
# 4    2016       Buri Ram           1500      76.6      27.4       8.5
# ..    ...            ...            ...       ...       ...       ...
# 380  2020     Udon Thani            941      75.0      27.0      13.0
# 381  2020    Uthai Thani            247      75.0      27.0      13.0
# 382  2020      Uttaradit            587      75.0      27.0      13.0
# 383  2020           Yala            436      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day
# 0        39.0   1638.0       130
# 1        39.0   1638.0       130
# 2        39.0   1638.0       130
# 3        39.0   1638.0       130
# 4        43.2   1370.7        93
# ..        ...      ...       ...
# 380      39.0   1638.0       130
# 381      39.0   1638.0       130
# 382      39.0   1638.0       130
# 383      39.0   1638.0       130
# 384      39.0   1638.0       130
#
# [385 rows x 9 columns]

# %%
df = df.rename(columns={'province': 'Province'})
df
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2016      Ang Thong            286      75.0      27.0      13.0
# 2    2016        Bangkok          14932      75.0      27.0      13.0
# 3    2016      Bueng Kan           1266      75.0      27.0      13.0
# 4    2016       Buri Ram           1500      76.6      27.4       8.5
# ..    ...            ...            ...       ...       ...       ...
# 380  2020     Udon Thani            941      75.0      27.0      13.0
# 381  2020    Uthai Thani            247      75.0      27.0      13.0
# 382  2020      Uttaradit            587      75.0      27.0      13.0
# 383  2020           Yala            436      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day
# 0        39.0   1638.0       130
# 1        39.0   1638.0       130
# 2        39.0   1638.0       130
# 3        39.0   1638.0       130
# 4        43.2   1370.7        93
# ..        ...      ...       ...
# 380      39.0   1638.0       130
# 381      39.0   1638.0       130
# 382      39.0   1638.0       130
# 383      39.0   1638.0       130
# 384      39.0   1638.0       130
#
# [385 rows x 9 columns]

# %%
coord = pd.read_csv('../Nuttawut/thailand_lalong.csv')
coord
# Out:
#          Province  latitude  longitude
# 0   Amnat Charoen   15.5100   104.3800
# 1       Ang Thong   14.3500   100.3100
# 2         Bangkok   13.4500   100.3500
# 3       Bueng Kan   18.2300   103.3700
# 4        Buri Ram   15.0000   103.0000
# ..            ...       ...        ...
# 72     Udon Thani   17.2900   102.4600
# 73    Uthai Thani   15.3835   100.0246
# 74      Uttaradit   17.3600   100.5000
# 75           Yala    6.5411   101.2804
# 76       Yasothon   15.5000   104.1000
#
# [77 rows x 3 columns]

# %%
df2 = pd.merge(df,coord,on='Province')
df2
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2017  Amnat Charoen            137      75.0      27.0      13.0
# 2    2018  Amnat Charoen            199      75.0      27.0      13.0
# 3    2019  Amnat Charoen            549      75.0      27.0      13.0
# 4    2020  Amnat Charoen            166      75.0      27.0      13.0
# ..    ...            ...            ...       ...       ...       ...
# 380  2016       Yasothon            686      75.0      27.0      13.0
# 381  2017       Yasothon            187      75.0      27.0      13.0
# 382  2018       Yasothon            409      75.0      27.0      13.0
# 383  2019       Yasothon            870      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day  latitude  longitude
# 0        39.0   1638.0       130     15.51     104.38
# 1        39.0   1638.0       130     15.51     104.38
# 2        39.0   1638.0       130     15.51     104.38
# 3        39.0   1638.0       130     15.51     104.38
# 4        39.0   1638.0       130     15.51     104.38
# ..        ...      ...       ...       ...        ...
# 380      39.0   1638.0       130     15.50     104.10
# 381      39.0   1638.0       130     15.50     104.10
# 382      39.0   1638.0       130     15.50     104.10
# 383      39.0   1638.0       130     15.50     104.10
# 384      39.0   1638.0       130     15.50     104.10
#
# [385 rows x 11 columns]

# %%
# np_coord = df2[['latitude', 'longitude','quant_rain']].to_numpy()
np_coord = df2[['latitude', 'longitude','rain_ml']].to_numpy()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(
    init="random",
    n_clusters=3,
    n_init=10,
    max_iter=300,
    random_state=42
)

# %%
kmeans.fit(np_coord)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2,
#        0, 0, 2, 0, 2, 2, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 1, 1, 2, 2,
#        2, 0, 2, 0, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 2, 2, 2,
#        2, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2,
#        0, 0, 0, 0, 2, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0,
#        0, 0, 2, 2, 2, 2, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0, 2, 2, 1, 2, 2,
#        2, 2, 0, 0, 0, 2, 2, 1, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2,
#        2, 2, 0, 0, 2, 0, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 2,
#        0, 2, 0, 0, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 2, 0, 2, 2, 0, 2, 1, 1, 1, 1, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2,
#        2, 2, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2, 2, 1, 2, 2, 2, 1, 1,
#        1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 2, 0, 0,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
centers =  kmeans.cluster_centers_
centers
# Out:
# array([[  15.51047419,  100.71095968, 1081.07822581],
#        [   9.32568333,  100.65724444, 4161.10555556],
#        [  13.58381235,  101.11951276, 1734.64485597]])

# %%
cluster = pd.DataFrame({'k_n':kmeans.labels_})
cluster
# Out:
#      k_n
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# ..   ...
# 380    2
# 381    2
# 382    2
# 383    2
# 384    2
#
# [385 rows x 1 columns]

# %%
df3 = df2.join(cluster)
df3
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2017  Amnat Charoen            137      75.0      27.0      13.0
# 2    2018  Amnat Charoen            199      75.0      27.0      13.0
# 3    2019  Amnat Charoen            549      75.0      27.0      13.0
# 4    2020  Amnat Charoen            166      75.0      27.0      13.0
# ..    ...            ...            ...       ...       ...       ...
# 380  2016       Yasothon            686      75.0      27.0      13.0
# 381  2017       Yasothon            187      75.0      27.0      13.0
# 382  2018       Yasothon            409      75.0      27.0      13.0
# 383  2019       Yasothon            870      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 0        39.0   1638.0       130     15.51     104.38    2
# 1        39.0   1638.0       130     15.51     104.38    2
# 2        39.0   1638.0       130     15.51     104.38    2
# 3        39.0   1638.0       130     15.51     104.38    2
# 4        39.0   1638.0       130     15.51     104.38    2
# ..        ...      ...       ...       ...        ...  ...
# 380      39.0   1638.0       130     15.50     104.10    2
# 381      39.0   1638.0       130     15.50     104.10    2
# 382      39.0   1638.0       130     15.50     104.10    2
# 383      39.0   1638.0       130     15.50     104.10    2
# 384      39.0   1638.0       130     15.50     104.10    2
#
# [385 rows x 12 columns]

# %%
df3['k_n'] = df3['k_n'].replace([0],100)
df3['k_n'] = df3['k_n'].replace([1],1)
df3['k_n'] = df3['k_n'].replace([2],10)
df3
# Out:
#      year       Province  patient_count  humidity  temp_avg  temp_min  \
# 0    2016  Amnat Charoen            676      75.0      27.0      13.0
# 1    2017  Amnat Charoen            137      75.0      27.0      13.0
# 2    2018  Amnat Charoen            199      75.0      27.0      13.0
# 3    2019  Amnat Charoen            549      75.0      27.0      13.0
# 4    2020  Amnat Charoen            166      75.0      27.0      13.0
# ..    ...            ...            ...       ...       ...       ...
# 380  2016       Yasothon            686      75.0      27.0      13.0
# 381  2017       Yasothon            187      75.0      27.0      13.0
# 382  2018       Yasothon            409      75.0      27.0      13.0
# 383  2019       Yasothon            870      75.0      27.0      13.0
# 384  2020       Yasothon            338      75.0      27.0      13.0
#
#      temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 0        39.0   1638.0       130     15.51     104.38   10
# 1        39.0   1638.0       130     15.51     104.38   10
# 2        39.0   1638.0       130     15.51     104.38   10
# 3        39.0   1638.0       130     15.51     104.38   10
# 4        39.0   1638.0       130     15.51     104.38   10
# ..        ...      ...       ...       ...        ...  ...
# 380      39.0   1638.0       130     15.50     104.10   10
# 381      39.0   1638.0       130     15.50     104.10   10
# 382      39.0   1638.0       130     15.50     104.10   10
# 383      39.0   1638.0       130     15.50     104.10   10
# 384      39.0   1638.0       130     15.50     104.10   10
#
# [385 rows x 12 columns]

# %%
df3 = df3.sort_values(by=['k_n'],ascending=1)
df3
# Out:
#      year      Province  patient_count  humidity  temp_avg  temp_min  \
# 161  2017    Narathiwat           1091      82.2      27.3      19.5
# 353  2019          Trat            635      81.0      27.9      18.2
# 350  2016          Trat            476      82.2      28.0      15.3
# 301  2017         Satun             73      80.7      27.7      20.0
# 316  2017      Songkhla           3009      79.9      27.9      22.6
# ..    ...           ...            ...       ...       ...       ...
# 283  2019  Samut Prakan           1325      74.3      29.1      18.4
# 212  2018   Phetchaburi            916      78.9      28.5      18.5
# 78   2019  Kanchanaburi            903      67.2      29.3      14.1
# 200  2016        Phayao            404      75.7      26.1       7.8
# 57   2018     Chon Buri           2748      76.0      28.9      18.5
#
#      temp_max  rain_ml  rain_day  latitude  longitude  k_n
# 161      35.5   4802.4       173    6.3000   101.4800    1
# 353      35.8   5287.3       185   12.2428   102.5175    1
# 350      35.7   5669.6       193   12.2428   102.5175    1
# 301      35.8   3039.0       201    6.4300   100.2000    1
# 316      36.0   3424.7       193    7.1300   100.3700    1
# ..        ...      ...       ...       ...        ...  ...
# 283      36.5    962.6        97   13.3200   100.4000  100
# 212      37.4   1033.9       111   13.0100    99.5500  100
# 78       42.5    687.4       130   14.0200    99.3100  100
# 200      41.5   1071.4       116   19.1100    99.5500  100
# 57       37.5   1332.8       119   13.2100   101.0100  100
#
# [385 rows x 12 columns]

# %%
df3['k_n'] = df3['k_n'].replace([100],'High')
df3['k_n'] = df3['k_n'].replace([10],'Medium')
df3['k_n'] = df3['k_n'].replace([1],'Low')
df3
# Out:
#      year      Province  patient_count  humidity  temp_avg  temp_min  \
# 161  2017    Narathiwat           1091      82.2      27.3      19.5
# 353  2019          Trat            635      81.0      27.9      18.2
# 350  2016          Trat            476      82.2      28.0      15.3
# 301  2017         Satun             73      80.7      27.7      20.0
# 316  2017      Songkhla           3009      79.9      27.9      22.6
# ..    ...           ...            ...       ...       ...       ...
# 283  2019  Samut Prakan           1325      74.3      29.1      18.4
# 212  2018   Phetchaburi            916      78.9      28.5      18.5
# 78   2019  Kanchanaburi            903      67.2      29.3      14.1
# 200  2016        Phayao            404      75.7      26.1       7.8
# 57   2018     Chon Buri           2748      76.0      28.9      18.5
#
#      temp_max  rain_ml  rain_day  latitude  longitude   k_n
# 161      35.5   4802.4       173    6.3000   101.4800   Low
# 353      35.8   5287.3       185   12.2428   102.5175   Low
# 350      35.7   5669.6       193   12.2428   102.5175   Low
# 301      35.8   3039.0       201    6.4300   100.2000   Low
# 316      36.0   3424.7       193    7.1300   100.3700   Low
# ..        ...      ...       ...       ...        ...   ...
# 283      36.5    962.6        97   13.3200   100.4000  High
# 212      37.4   1033.9       111   13.0100    99.5500  High
# 78       42.5    687.4       130   14.0200    99.3100  High
# 200      41.5   1071.4       116   19.1100    99.5500  High
# 57       37.5   1332.8       119   13.2100   101.0100  High
#
# [385 rows x 12 columns]

# %%
df3 = df3.rename(columns={'k_n': 'rain_amount'})

# %%
df3 = df3.loc[df3['year'] == 2019]
df3
# Out:
#      year      Province  patient_count  humidity  temp_avg  temp_min  \
# 353  2019          Trat            635      81.0      27.9      18.2
# 253  2019        Ranong            194      78.5      27.7      20.3
# 238  2019        Phuket            585      75.4      29.2      23.2
# 268  2019        Roi Et           3802      70.0      28.4      12.7
# 178  2019    Nonthaburi           1486      75.0      27.0      13.0
# ..    ...           ...            ...       ...       ...       ...
# 278  2019  Sakon Nakhon            918      71.2      27.5      10.0
# 83   2019     Khon Kaen           3550      67.2      28.4      11.1
# 213  2019   Phetchaburi            973      76.0      29.0      17.5
# 283  2019  Samut Prakan           1325      74.3      29.1      18.4
# 78   2019  Kanchanaburi            903      67.2      29.3      14.1
#
#      temp_max  rain_ml  rain_day  latitude  longitude rain_amount
# 353      35.8   5287.3       185   12.2428   102.5175         Low
# 253      37.2   3828.7       183    9.5600    98.4000         Low
# 238      39.2   1688.8       149    7.5300    98.2400      Medium
# 268      41.3   1530.7       130   16.4000   103.4000      Medium
# 178      39.0   1638.0       130   13.5100   100.3400      Medium
# ..        ...      ...       ...       ...        ...         ...
# 278      40.5   1213.0       109   17.1000   104.9000        High
# 83       41.5   1068.6        96   16.3000   102.4700        High
# 213      38.4    585.6        90   13.0100    99.5500        High
# 283      36.5    962.6        97   13.3200   100.4000        High
# 78       42.5    687.4       130   14.0200    99.3100        High
#
# [77 rows x 12 columns]

# %%
# plt = sns.scatterplot(data=df3, x="latitude", y="longitude", hue="k_n" )
# plt.axis('equal')

# %%
#print(min(df3['latitude']),max(df3['latitude']),min(df3['longitude']),max(df3['longitude']))

# %%
# import map
ruh_m = plt.imread('../Akkapop/img/map.jpg')

# %%
# Set edge
maps = pd.DataFrame(data={"lat":[97.313,105.785], "lon":[20.556,5.468]})
maps
# Out:
#        lat     lon
# 0   97.313  20.556
# 1  105.785   5.468

# %%
# Set map edge
BBox = ( maps['lat'].min(), 
         maps['lat'].max(),
         maps['lon'].min(), 
         maps['lon'].max())
BBox
# Out:
# (97.313, 105.785, 5.468, 20.556)

# %%
fig, ax = plt.subplots(figsize = (8,7))
hmax = sns.scatterplot(
    data=df3, x="longitude", y="latitude",
    hue="rain_amount" , palette=['green','blue','red'], 
    size="patient_count" , sizes=(1,300) , alpha = 0.5 )
# ax.scatter(df3.longitude, df3.latitude, alpha=0.3, c=df3.k_n, s=df3.dead_perc*1000)
hmax.scatter(centers[:, 1], centers[:, 0], s=1000, alpha=0.1)
hmax.set_title('Plotting Spatial Data on Riyadh Map')
hmax.set_xlim(BBox[0],BBox[1])
hmax.set_ylim(BBox[2],BBox[3])
hmax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
